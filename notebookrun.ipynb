# %%
# %cd "/Users/nadezdaurcenko/Desktop/Модельный аппарат/SeasonalAdjustment/sa_ru_python"
# %run run_sa.py
# Out:
# /Users/nadezdaurcenko/Desktop/Модельный аппарат/SeasonalAdjustment/sa_ru_python
# Данные: 44 рядов, 2002-01 .. 2026-08
# Настройки: лист 'config' в inflcomponents_nonSA.xlsx
# [1/44] Мясопродукты ...
#     OK | заморожено | календарь=basic | seats | ARIMA (2 1 0)(0 1 1) | выбросов 12 | QS p=0.011
# [2/44] Рыбопродукты ...
#     OK | заморожено | календарь=none | seats | ARIMA (1 1 1)(0 1 1) | выбросов 9 | QS p=0.022
# [3/44] Масло и жиры ...
#     NO_SEASONALITY | заморожено | календарь=none |  | ARIMA (1 1 1)(1 0 0) | выбросов 5
# [4/44] Молоко и молочная продукция ...
#     OK | заморожено | календарь=none | seats | ARIMA (2 1 0)(0 1 1) | выбросов 10 | QS p=0.000
# [5/44] Сыр ...
#     OK | заморожено | календарь=none | seats | ARIMA (2 1 0)(0 1 1) | выбросов 5 | QS p=0.000
# [6/44] Яйца ...
#     OK | заморожено | календарь=none | seats | ARIMA (0 1 2)(0 1 1) | выбросов 1 | QS p=0.000
# [7/44] Сахар ...
# ...
